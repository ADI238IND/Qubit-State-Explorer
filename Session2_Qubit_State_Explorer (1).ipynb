# %%
# !pip install qiskit qiskit-aer pylatexenc
# Out:
# Collecting qiskit
#   Downloading qiskit-2.5.0-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (14 kB)
# Collecting qiskit-aer
#   Downloading qiskit_aer-0.17.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.3 kB)
# Collecting pylatexenc
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy<3,>=2.0 in /usr/local/lib/python3.12/dist-packages (from qiskit) (2.0.2)
# Requirement already satisfied: scipy>=1.14 in /usr/local/lib/python3.12/dist-packages (from qiskit) (1.16.3)
# Collecting rustworkx>=0.15.0 (from qiskit)
#   Downloading rustworkx-0.18.0-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit) (0.3.8)
# Collecting stevedore>=3.0.0 (from qiskit)
#   Downloading stevedore-5.9.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit) (4.15.0)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (5.9.5)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.0->qiskit-aer) (1.17.0)
# Downloading qiskit-2.5.0-cp310-abi3-manylinux_2_28_x86_64.whl (9.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 106.7 MB/s eta 0:00:00
# Downloading qiskit_aer-0.17.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 100.4 MB/s eta 0:00:00
# Downloading rustworkx-0.18.0-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 99.5 MB/s eta 0:00:00
# Downloading stevedore-5.9.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.6 MB/s eta 0:00:00
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (setup.py) ... done
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136817 sha256=1e5b429afd667a4edb2e58e5187f15b68b6fb20ba541950fc70f1a423feda139
#   Stored in directory: /root/.cache/pip/wheels/06/3e/78/fa1588c1ae991bbfd814af2bcac6cef7a178beee1939180d46
# Successfully built pylatexenc
# Installing collected packages: pylatexenc, stevedore, rustworkx, qiskit, qiskit-aer
# Successfully installed pylatexenc-2.10 qiskit-2.5.0 qiskit-aer-0.17.2 rustworkx-0.18.0 stevedore-5.9.0

# %%
import numpy as np

# !pip install qiskit qiskit-aer pylatexenc

from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector

from qiskit.visualization import plot_bloch_multivector

import matplotlib.pyplot as plt
# Out:
# Collecting qiskit
#   Downloading qiskit-2.5.0-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (14 kB)
# Collecting qiskit-aer
#   Downloading qiskit_aer-0.17.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.3 kB)
# Collecting pylatexenc
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 1.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy<3,>=2.0 in /usr/local/lib/python3.12/dist-packages (from qiskit) (2.0.2)
# Requirement already satisfied: scipy>=1.14 in /usr/local/lib/python3.12/dist-packages (from qiskit) (1.16.3)
# Collecting rustworkx>=0.15.0 (from qiskit)
#   Downloading rustworkx-0.18.0-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit) (0.3.8)
# Collecting stevedore>=3.0.0 (from qiskit)
#   Downloading stevedore-5.9.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit) (4.15.0)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (5.9.5)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.0->qiskit-aer) (1.17.0)
# Downloading qiskit-2.5.0-cp310-abi3-manylinux_2_28_x86_64.whl (9.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 32.2 MB/s eta 0:00:00
# Downloading qiskit_aer-0.17.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 54.3 MB/s eta 0:00:00
# Downloading rustworkx-0.18.0-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 95.9 MB/s eta 0:00:00
# Downloading stevedore-5.9.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.8 MB/s eta 0:00:00
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (setup.py) ... done
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136817 sha256=d5c4df749fe9d6ff33b4a90e4795efd9796b5c974b3ef05080e5418e98a3e6be
#   Stored in directory: /root/.cache/pip/wheels/06/3e/78/fa1588c1ae991bbfd814af2bcac6cef7a178beee1939180d46
# Successfully built pylatexenc
# Installing collected packages: pylatexenc, stevedore, rustworkx, qiskit, qiskit-aer
# Successfully installed pylatexenc-2.10 qiskit-2.5.0 qiskit-aer-0.17.2 rustworkx-0.18.0 stevedore-5.9.0

# %%
import numpy as np

from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector
import matplotlib.pyplot as plt

print("Qubit State Explorer")
print("1. X Gate")
print("2. Y Gate")
print("3. Z Gate")
print("4. Hadamard Gate")
print("5. RY Gate")

choice = input("Choose a gate (1-5): ")

qc = QuantumCircuit(1)

if choice == "1":
    qc.x(0)
elif choice == "2":
    qc.y(0)
elif choice == "3":
    qc.z(0)
elif choice == "4":
    qc.h(0)
elif choice == "5":
    theta = float(input("Enter theta (radians): "))
    qc.ry(theta,0)
else:
    print("Invalid Choice")
    exit()

state = Statevector.from_instruction(qc)

probabilities = state.probabilities()

print("\nMeasurement Probabilities")
print("-------------------------")
print("|0> =", probabilities[0])
print("|1> =", probabilities[1])

print("\nQuantum Circuit")

display(qc.draw("mpl"))

bloch_fig = plot_bloch_multivector(state)
display(bloch_fig)
# Out:
# Qubit State Explorer
# 1. X Gate
# 2. Y Gate
# 3. Z Gate
# 4. Hadamard Gate
# 5. RY Gate
# Choose a gate (1-5): 5
# Enter theta (radians): 45
#
# Measurement Probabilities
# -------------------------
# |0> = 0.7626609944088648
# |1> = 0.23733900559113516
#
# Quantum Circuit
